# %% [markdown]
# <a href="https://colab.research.google.com/github/andre-arantes/ia/blob/master/tp1/RandomForest.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Projeto de Previsão de Diabetes
#
# Este projeto tem como objetivo prever a probabilidade de uma pessoa ter diabetes com base em vários fatores, como idade, nível de HbA1c, nível de glicose no sangue e gênero. O conjunto de dados usado neste projeto é o Diabetes Prediction Dataset.
#
# Usaremos o algoritmo Random Forest Classifier para treinar nosso modelo e prever a probabilidade de diabetes. Também usaremos várias técnicas de pré-processamento de dados, como subamostragem, para melhorar a precisão do nosso modelo.

# %%
# Importando bibliotecas
import pandas as pd
from sklearn import preprocessing
import seaborn as sns
from sklearn.model_selection import train_test_split
from imblearn.under_sampling import RandomUnderSampler
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report

# %%
# Carregando os dados
base = pd.read_csv('/content/sample_data/diabetes_prediction_dataset.csv')

# %% [markdown]
# # Ler dados da base

# %%
base.head()
# Out:
#    gender   age  hypertension  heart_disease smoking_history    bmi  \
# 0  Female  80.0             0              1           never  25.19
# 1  Female  54.0             0              0         No Info  27.32
# 2    Male  28.0             0              0           never  27.32
# 3  Female  36.0             0              0         current  23.45
# 4    Male  76.0             1              1         current  20.14
#
#    HbA1c_level  blood_glucose_level  diabetes
# 0          6.6                  140         0
# 1          6.6                   80         0
# 2          5.7                  158         0
# 3          5.0                  155         0
# 4          4.8                  155         0

# %%
# checar existencias de campos nulos
base.isnull().sum()
# Out:
# gender                 0
# age                    0
# hypertension           0
# heart_disease          0
# smoking_history        0
# bmi                    0
# HbA1c_level            0
# blood_glucose_level    0
# diabetes               0
# dtype: int64

# %%
# checar natureza dos dados
for i in base.columns:
    print(base[i].value_counts())
    print('\n')
# Out:
# Female    58552
# Male      41430
# Other        18
# Name: gender, dtype: int64
#
#
# 80.00    5621
# 51.00    1619
# 47.00    1574
# 48.00    1568
# 53.00    1542
#          ...
# 0.48       83
# 1.00       83
# 0.40       66
# 0.16       59
# 0.08       36
# Name: age, Length: 102, dtype: int64
#
#
# 0    92515
# 1     7485
# Name: hypertension, dtype: int64
#
#
# 0    96058
# 1     3942
# Name: heart_disease, dtype: int64
#
#
# No Info        35816
# never          35095
# former          9352
# current         9286
# not current     6447
# ever            4004
# Name: smoking_history, dtype: int64
#
#
# 27.32    25495
# 23.00      103
# 27.12      101
# 27.80      100
# 24.96      100
#          ...
# 58.23        1
# 48.18        1
# 55.57        1
# 57.07        1
# 60.52        1
# Name: bmi, Length: 4247, dtype: int64
#
#
# 6.6    8540
# 5.7    8413
# 6.5    8362
# 5.8    8321
# 6.0    8295
# 6.2    8269
# 6.1    8048
# 3.5    7662
# 4.8    7597
# 4.5    7585
# 4.0    7542
# 5.0    7471
# 8.8     661
# 8.2     661
# 9.0     654
# 7.5     643
# 6.8     642
# 7.0     634
# Name: HbA1c_level, dtype: int64
#
#
# 130    7794
# 159    7759
# 140    7732
# 160    7712
# 126    7702
# 145    7679
# 200    7600
# 155    7575
# 90     7112
# 80     7106
# 158    7026
# 100    7025
# 85     6901
# 280     729
# 300     674
# 240     636
# 260     635
# 220     603
# Name: blood_glucose_level, dtype: int64
#
#
# 0    91500
# 1     8500
# Name: diabetes, dtype: int64

# %% [markdown]
# **Separando os atributos de entrada e de classe**

# %%
X = base.copy()
y = X.pop('diabetes')

# %% [markdown]
# #Pré-processamento dos dados

# %%
# remover campo 'smoking_history' devido a quantidade de informações faltantes
X.drop('smoking_history',axis=1,inplace=True)

from sklearn.preprocessing import LabelEncoder
label_encoder = LabelEncoder()
label_encoder_gender = LabelEncoder()
X.iloc[:,0] = label_encoder_gender.fit_transform(X.iloc[:,0])
# Out:
# <ipython-input-40-2778dbb9c2a5>:7: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   X.iloc[:,0] = label_encoder_gender.fit_transform(X.iloc[:,0])

# %% [markdown]
# **Divisão dos dados em treino e teste**
#
# foi feita a divisão dos dados em 80\% para treino e 20\% para teste.

# %%
X_treino, X_teste, y_treino, y_teste = train_test_split(X, y, test_size = 0.20, random_state = 42)

# %% [markdown]
# **Balanciamento dos dados**
#
# Para o balanceamento de dados, foi verificado que haviam muitas instâncias da classe majoritária, então foi decidido implementar o undersampling na base de treino.

# %%
from imblearn.under_sampling import RandomUnderSampler
# balanceia a base de dados de forma que a base majoritaria fique 40% maior
us=RandomUnderSampler(sampling_strategy=0.4)
X_treino,y_treino = us.fit_resample(X_treino,y_treino)

# %% [markdown]
# **Examine o Random Forest Padrão para Determinar Parâmetros.**

# %%
modelo = RandomForestClassifier(random_state = 0)
from pprint import pprint

# Look at parameters used by our current forest
print('Parameters currently in use:\n')
pprint(modelo.get_params())
# Out:
# Parameters currently in use:
#
# {'bootstrap': True,
#  'ccp_alpha': 0.0,
#  'class_weight': None,
#  'criterion': 'gini',
#  'max_depth': None,
#  'max_features': 'sqrt',
#  'max_leaf_nodes': None,
#  'max_samples': None,
#  'min_impurity_decrease': 0.0,
#  'min_samples_leaf': 1,
#  'min_samples_split': 2,
#  'min_weight_fraction_leaf': 0.0,
#  'n_estimators': 100,
#  'n_jobs': None,
#  'oob_score': False,
#  'random_state': 0,
#  'verbose': 0,
#  'warm_start': False}

# %% [markdown]
# #Random Search com Cross Validation
#
# Para montagem do RandomGrid, foi utilizado os seguintes parametros: quantidade de árvores (40 a 400), cálculo para quantidade de atributos (log2 ou sqrt), profundidade máxima da árvore (1 a 20 ou sem limite), mínimo de samples para dividir um nó (2 3 ou 5), numero mínimo de samples em cada folha da árvore (1, 2 ou 4) e uso de bootstrap (verdadeiro ou falso).

# %%
from sklearn.model_selection import RandomizedSearchCV
import numpy as np

# Number of trees in random forest
n_estimators = [int(x) for x in np.linspace(start = 40, stop = 400, num = 10)]
# Number of features to consider at every split
max_features = ['log2', 'sqrt']
# Maximum number of levels in tree
max_depth = [int(x) for x in np.linspace(1, 20, num = 3)]
max_depth.append(None)
# Minimum number of samples required to split a node
min_samples_split = [2, 5, 10]
# Minimum number of samples required at each leaf node
min_samples_leaf = [1, 2, 4]
# Method of selecting samples for training each tree
bootstrap = [True, False]

# Create the random grid
random_grid = {'n_estimators': n_estimators,
               'max_features': max_features,
               'max_depth': max_depth,
               'min_samples_split': min_samples_split,
               'min_samples_leaf': min_samples_leaf,
               'bootstrap': bootstrap}

pprint(random_grid)
# Out:
# {'bootstrap': [True, False],
#  'max_depth': [1, 10, 20, None],
#  'max_features': ['log2', 'sqrt'],
#  'min_samples_leaf': [1, 2, 4],
#  'min_samples_split': [2, 5, 10],
#  'n_estimators': [40, 80, 120, 160, 200, 240, 280, 320, 360, 400]}

# %% [markdown]
# **RandomSerach com cross validation**
#
# RandomizedSearchCV com o RandomGrid como um de seus parâmetros, além do kfold (5) percorrendo 100 combinações e com o scoring buscando o melhor recall da classe 1.

# %%
from sklearn.metrics import make_scorer, recall_score

# Create a custom scoring function for recall of class 1
scoring = {'Recall_Class1': make_scorer(recall_score, pos_label=1)}

# Random search of parameters, using 5 fold cross validation,
# search across 100 different combinations, and use all available cores
rf_random = RandomizedSearchCV(estimator=modelo, param_distributions=random_grid,
                              n_iter = 100, scoring=scoring,refit='Recall_Class1',
                              cv = 5, verbose=2, random_state=0, n_jobs=-1,
                              return_train_score=True)

# Fit the random search model
rf_random.fit(X_treino, y_treino)
# Out:
# Fitting 5 folds for each of 100 candidates, totalling 500 fits
# RandomizedSearchCV(cv=5, estimator=RandomForestClassifier(random_state=0),
#                    n_iter=100, n_jobs=-1,
#                    param_distributions={'bootstrap': [True, False],
#                                         'max_depth': [1, 10, 20, None],
#                                         'max_features': ['log2', 'sqrt'],
#                                         'min_samples_leaf': [1, 2, 4],
#                                         'min_samples_split': [2, 5, 10],
#                                         'n_estimators': [40, 80, 120, 160, 200,
#                                                          240, 280, 320, 360,
#                                                          400]},
#                    random_state=0, refit='Recall_Class1',
#                    return_train_score=True,
#                    scoring={'Recall_Class1': make_scorer(recall_score, pos_label=1)},
#                    verbose=2)

# %% [markdown]
# **Avaliação do modelo base**
#
# A avaliação do modelo é feita a partir do recall da classe verdadeira (tem diabetes)

# %%
def evaluate(model, test_features, test_labels):
    previsoes = model.predict(test_features)
    cr = classification_report(test_labels, previsoes, output_dict=True)['1']['recall']
    return cr

# %%
base_model = RandomForestClassifier(random_state = 0)
base_model.fit(X_treino, y_treino)
base_recall = evaluate(base_model, X_teste, y_teste)
base_recall
# Out:
# 0.8079625292740047

# %% [markdown]
# **avaliação do melhor modelo**

# %%
best_random = rf_random.best_estimator_
random_recall = evaluate(best_random, X_teste, y_teste)
random_recall
# Out:
# 0.810304449648712

# %%
print('Improvement of {:0.2f}%.'.format( 100 * (random_recall - base_recall) / base_recall))
# Out:
# Improvement of 0.29%.

# %%
rf_random.best_params_
# Out:
# {'n_estimators': 200,
#  'min_samples_split': 2,
#  'min_samples_leaf': 1,
#  'max_features': 'log2',
#  'max_depth': None,
#  'bootstrap': False}

# %%
rf_random.cv_results_
# Out:
# {'mean_fit_time': array([ 1.85082049,  1.49434938,  7.29233088,  2.81583734,  0.6981133 ,
#          4.49384947,  8.51577015,  6.0908649 ,  7.3856997 ,  9.114856  ,
#          8.66757312,  2.7173214 ,  1.11781611,  5.95895095,  1.08361015,
#          6.46036763,  5.83845782,  4.21065879,  4.18525376,  9.11607208,
#          2.12012796,  3.25963435,  2.10178242,  1.89474683, 11.33501606,
#          1.15990796,  0.83608885,  3.5142437 ,  4.08258839,  2.90149059,
#          0.65375047,  1.83778081,  5.99505978,  7.02131362,  7.34572406,
#          3.04848051,  7.80584078,  2.38140812,  2.1680469 ,  7.1583415 ,
#          1.35293503,  1.106251  ,  7.00662909,  1.48223548,  8.22245941,
#          6.72069321,  2.52071247,  6.68461823,  0.69824429,  1.51154795,
#          2.65431452,  8.18744874,  0.52358384,  3.63030467,  0.57814951,
#          5.34284587,  8.47615352,  4.21387582, 10.74303627,  4.09697313,
#          1.44559817,  2.97245502,  3.62915816,  0.24252882,  2.17206335,
#          6.92624211,  1.38932996,  7.01347466,  7.4397728 ,  3.82502041,
#          1.86368556,  3.39544687,  4.19986677,  3.31537614,  6.7068604 ,
#          2.45142145,  6.20146022,  4.89971795,  5.62831845,  7.05264144,
#          5.48390532,  1.74378862,  4.37982044,  1.0733151 ,  2.79495034,
#          3.23880811,  0.85602307,  0.29300976,  1.03716259,  2.7277741 ,
#          0.23984027,  5.91990852,  8.6002367 ,  2.22283087,  9.63765903,
#         10.10835919,  0.65944324,  7.96230035, 10.71238894,  4.69093456]),
#  'std_fit_time': array([0.55543571, 0.01439359, 0.57491558, 0.61340002, 0.24737965,
#         0.47688954, 0.807651  , 0.6415041 , 0.59488457, 0.62985839,
#         0.6612046 , 0.60953509, 0.36860488, 0.82743549, 0.09209217,
#         0.56361402, 0.79352147, 0.74459334, 0.7541149 , 0.56458338,
#         0.54308912, 0.37395806, 0.63662479, 0.02373819, 0.56628155,
#         0.3326787 , 0.02372777, 0.48490381, 0.61997913, 0.60469633,
#         0.21672484, 0.02528825, 0.78580786, 0.72719047, 0.69449656,
#         0.05975405, 0.53316445, 0.32763209, 0.04578661, 0.65551304,
#         0.02239565, 0.3175016 , 0.62144924, 0.30575924, 0.59973281,
#         0.04015578, 0.05353136, 0.10877756, 0.00386261, 0.00232947,
#         0.04108184, 0.14500726, 0.01271028, 0.05496752, 0.009644  ,
#         0.01200357, 0.01793699, 0.07326711, 0.01920323, 0.00708904,
#         0.01975088, 0.00757165, 0.07137578, 0.00114931, 0.0483122 ,
#         0.11524968, 0.04041919, 0.12303502, 0.03577288, 0.09267303,
#         0.00345484, 0.05916935, 0.07492106, 0.04676766, 0.00392641,
#         0.05864987, 0.10677762, 0.11429215, 0.08163132, 0.09739872,
#         0.00937897, 0.00495804, 0.00732527, 0.0025907 , 0.04543534,
#         0.05295884, 0.00923836, 0.00040863, 0.00222652, 0.04020154,
#         0.00132167, 0.01318386, 0.16310036, 0.04715561, 0.01253876,
#         0.02624108, 0.00143848, 0.00580918, 0.01365116, 0.07225458]),
#  'param_n_estimators': masked_array(data=[200, 80, 280, 160, 80, 200, 360, 360, 320, 320, 400,
#                     120, 120, 280, 40, 360, 280, 200, 200, 320, 120, 200,
#                     80, 80, 400, 160, 120, 200, 200, 160, 80, 120, 280,
#                     400, 360, 160, 280, 360, 320, 320, 200, 120, 400, 200,
#                     400, 240, 160, 240, 120, 80, 80, 400, 80, 200, 80, 240,
#                     400, 200, 400, 240, 40, 120, 160, 40, 240, 320, 200,
#                     320, 360, 400, 120, 160, 160, 120, 320, 360, 320, 240,
#                     200, 280, 240, 80, 240, 40, 120, 160, 120, 40, 40, 120,
#                     40, 200, 400, 120, 360, 360, 40, 400, 400, 240],
#               mask=[False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False],
#         fill_value='?',
#              dtype=object),
#  'param_min_samples_split': masked_array(data=[2, 5, 10, 2, 10, 2, 2, 2, 5, 5, 5, 5, 2, 10, 2, 10, 10,
#                     10, 10, 2, 2, 5, 10, 5, 10, 5, 10, 5, 2, 5, 2, 10, 2,
#                     10, 2, 10, 2, 10, 5, 10, 2, 10, 2, 10, 5, 5, 5, 5, 10,
#                     5, 2, 5, 2, 10, 5, 2, 10, 10, 10, 5, 10, 10, 2, 2, 10,
#                     2, 5, 5, 2, 2, 10, 5, 2, 10, 10, 10, 10, 2, 2, 5, 10,
#                     2, 10, 5, 10, 2, 5, 10, 5, 2, 5, 2, 10, 5, 10, 10, 2,
#                     2, 5, 10],
#               mask=[False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False],
#         fill_value='?',
#              dtype=object),
#  'param_min_samples_leaf': masked_array(data=[2, 4, 4, 4, 2, 1, 1, 1, 1, 2, 2, 1, 4, 2, 2, 4, 4, 4,
#                     1, 2, 1, 4, 1, 4, 2, 2, 2, 2, 4, 2, 2, 1, 2, 1, 4, 4,
#                     2, 1, 1, 1, 1, 2, 1, 2, 2, 1, 4, 4, 1, 4, 1, 4, 2, 1,
#                     4, 2, 4, 2, 4, 2, 1, 1, 2, 4, 4, 2, 1, 1, 1, 4, 2, 2,
#                     4, 4, 2, 1, 4, 4, 2, 4, 1, 2, 1, 1, 4, 1, 2, 4, 1, 1,
#                     4, 1, 1, 4, 1, 2, 1, 4, 4, 2],
#               mask=[False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False],
#         fill_value='?',
#              dtype=object),
#  'param_max_features': masked_array(data=['log2', 'sqrt', 'sqrt', 'sqrt', 'sqrt', 'log2', 'log2',
#                     'sqrt', 'sqrt', 'log2', 'sqrt', 'sqrt', 'sqrt', 'sqrt',
#                     'sqrt', 'log2', 'sqrt', 'log2', 'sqrt', 'log2', 'log2',
#                     'log2', 'sqrt', 'sqrt', 'sqrt', 'sqrt', 'sqrt', 'log2',
#                     'sqrt', 'log2', 'log2', 'log2', 'sqrt', 'sqrt', 'sqrt',
#                     'sqrt', 'log2', 'sqrt', 'sqrt', 'sqrt', 'log2', 'log2',
#                     'sqrt', 'log2', 'sqrt', 'log2', 'log2', 'log2', 'log2',
#                     'log2', 'log2', 'sqrt', 'sqrt', 'log2', 'sqrt', 'sqrt',
#                     'sqrt', 'sqrt', 'log2', 'sqrt', 'log2', 'log2', 'log2',
#                     'sqrt', 'sqrt', 'sqrt', 'sqrt', 'log2', 'sqrt', 'sqrt',
#                     'sqrt', 'log2', 'sqrt', 'log2', 'log2', 'log2', 'log2',
#                     'log2', 'sqrt', 'log2', 'log2', 'sqrt', 'sqrt', 'log2',
#                     'log2', 'sqrt', 'log2', 'log2', 'sqrt', 'log2', 'log2',
#                     'log2', 'sqrt', 'sqrt', 'log2', 'log2', 'sqrt', 'log2',
#                     'log2', 'log2'],
#               mask=[False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False],
#         fill_value='?',
#              dtype=object),
#  'param_max_depth': masked_array(data=[1, 10, 20, 10, 1, 20, None, 10, 20, 20, None, None, 1,
#                     None, None, 10, None, 10, 10, None, 10, 10, None, None,
#                     None, 1, 1, 10, 10, 10, 1, 10, 10, 10, 10, None, 20, 1,
#                     1, 20, 1, 1, 10, 1, 10, 20, 10, None, 1, 10, 20, 20, 1,
#                     10, 1, None, 20, 10, 20, 10, None, None, 20, 1, 1,
#                     None, 1, None, 10, 1, 10, 10, 20, None, None, 1, 10,
#                     20, None, 20, None, 10, 10, None, 20, 10, 1, 1, 20, 10,
#                     1, None, 20, 10, None, None, 10, 10, None, 10],
#               mask=[False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False],
#         fill_value='?',
#              dtype=object),
#  'param_bootstrap': masked_array(data=[True, False, False, True, True, True, True, True, True,
#                     False, True, True, True, True, False, True, True,
#                     False, False, False, True, True, True, False, False,
#                     False, True, True, False, True, True, True, False,
#                     True, False, True, False, False, True, True, True,
#                     True, True, True, False, False, True, False, False,
#                     False, False, True, False, True, True, True, True,
#                     False, False, True, False, False, True, False, True,
#                     True, False, True, False, True, True, False, False,
#                     False, True, False, False, True, False, False, True,
#                     False, True, False, True, False, False, True, False,
#                     False, False, False, True, True, False, False, True,
#                     False, False, False],
#               mask=[False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False],
#         fill_value='?',
#              dtype=object),
#  'params': [{'n_estimators': 200,
#    'min_samples_split': 2,
#    'min_samples_leaf': 2,
#    'max_features': 'log2',
#    'max_depth': 1,
#    'bootstrap': True},
#   {'n_estimators': 80,
#    'min_samples_split': 5,
#    'min_samples_leaf': 4,
#    'max_features': 'sqrt',
#    'max_depth': 10,
#    'bootstrap': False},
#   {'n_estimators': 280,
#    'min_samples_split': 10,
#    'min_samples_leaf': 4,
#    'max_features': 'sqrt',
#    'max_depth': 20,
#    'bootstrap': False},
#   {'n_estimators': 160,
#    'min_samples_split': 2,
#    'min_samples_leaf': 4,
#    'max_features': 'sqrt',
#    'max_depth': 10,
#    'bootstrap': True},
#   {'n_estimators': 80,
#    'min_samples_split': 10,
#    'min_samples_leaf': 2,
#    'max_features': 'sqrt',
#    'max_depth': 1,
#    'bootstrap': True},
#   {'n_estimators': 200,
#    'min_samples_split': 2,
#    'min_samples_leaf': 1,
#    'max_features': 'log2',
#    'max_depth': 20,
#    'bootstrap': True},
#   {'n_estimators': 360,
#    'min_samples_split': 2,
#    'min_samples_leaf': 1,
#    'max_features': 'log2',
#    'max_depth': None,
#    'bootstrap': True},
#   {'n_estimators': 360,
#    'min_samples_split': 2,
#    'min_samples_leaf': 1,
#    'max_features': 'sqrt',
#    'max_depth': 10,
#    'bootstrap': True},
#   {'n_estimators': 320,
#    'min_samples_split': 5,
#    'min_samples_leaf': 1,
#    'max_features': 'sqrt',
#    'max_depth': 20,
#    'bootstrap': True},
#   {'n_estimators': 320,
#    'min_samples_split': 5,
#    'min_samples_leaf': 2,
#    'max_features': 'log2',
#    'max_depth': 20,
#    'bootstrap': False},
#   {'n_estimators': 400,
#    'min_samples_split': 5,
#    'min_samples_leaf': 2,
#    'max_features': 'sqrt',
#    'max_depth': None,
#    'bootstrap': True},
#   {'n_estimators': 120,
#    'min_samples_split': 5,
#    'min_samples_leaf': 1,
#    'max_features': 'sqrt',
#    'max_depth': None,
#    'bootstrap': True},
#   {'n_estimators': 120,
#    'min_samples_split': 2,
#    'min_samples_leaf': 4,
#    'max_features': 'sqrt',
#    'max_depth': 1,
#    'bootstrap': True},
#   {'n_estimators': 280,
#    'min_samples_split': 10,
#    'min_samples_leaf': 2,
#    'max_features': 'sqrt',
#    'max_depth': None,
#    'bootstrap': True},
#   {'n_estimators': 40,
#    'min_samples_split': 2,
#    'min_samples_leaf': 2,
#    'max_features': 'sqrt',
#    'max_depth': None,
#    'bootstrap': False},
#   {'n_estimators': 360,
#    'min_samples_split': 10,
#    'min_samples_leaf': 4,
#    'max_features': 'log2',
#    'max_depth': 10,
#    'bootstrap': True},
#   {'n_estimators': 280,
#    'min_samples_split': 10,
#    'min_samples_leaf': 4,
#    'max_features': 'sqrt',
#    'max_depth': None,
#    'bootstrap': True},
#   {'n_estimators': 200,
#    'min_samples_split': 10,
#    'min_samples_leaf': 4,
#    'max_features': 'log2',
#    'max_depth': 10,
#    'bootstrap': False},
#   {'n_estimators': 200,
#    'min_samples_split': 10,
#    'min_samples_leaf': 1,
#    'max_features': 'sqrt',
#    'max_depth': 10,
#    'bootstrap': False},
#   {'n_estimators': 320,
#    'min_samples_split': 2,
#    'min_samples_leaf': 2,
#    'max_features': 'log2',
#    'max_depth': None,
#    'bootstrap': False},
#   {'n_estimators': 120,
#    'min_samples_split': 2,
#    'min_samples_leaf': 1,
#    'max_features': 'log2',
#    'max_depth': 10,
#    'bootstrap': True},
#   {'n_estimators': 200,
#    'min_samples_split': 5,
#    'min_samples_leaf': 4,
#    'max_features': 'log2',
#    'max_depth': 10,
#    'bootstrap': True},
#   {'n_estimators': 80,
#    'min_samples_split': 10,
#    'min_samples_leaf': 1,
#    'max_features': 'sqrt',
#    'max_depth': None,
#    'bootstrap': True},
#   {'n_estimators': 80,
#    'min_samples_split': 5,
#    'min_samples_leaf': 4,
#    'max_features': 'sqrt',
#    'max_depth': None,
#    'bootstrap': False},
#   {'n_estimators': 400,
#    'min_samples_split': 10,
#    'min_samples_leaf': 2,
#    'max_features': 'sqrt',
#    'max_depth': None,
#    'bootstrap': False},
#   {'n_estimators': 160,
#    'min_samples_split': 5,
#    'min_samples_leaf': 2,
#    'max_features': 'sqrt',
#    'max_depth': 1,
#    'bootstrap': False},
#   {'n_estimators': 120,
#    'min_samples_split': 10,
#    'min_samples_leaf': 2,
#    'max_features': 'sqrt',
#    'max_depth': 1,
#    'bootstrap': True},
#   {'n_estimators': 200,
#    'min_samples_split': 5,
#    'min_samples_leaf': 2,
#    'max_features': 'log2',
#    'max_depth': 10,
#    'bootstrap': True},
#   {'n_estimators': 200,
#    'min_samples_split': 2,
#    'min_samples_leaf': 4,
#    'max_features': 'sqrt',
#    'max_depth': 10,
#    'bootstrap': False},
#   {'n_estimators': 160,
#    'min_samples_split': 5,
#    'min_samples_leaf': 2,
#    'max_features': 'log2',
#    'max_depth': 10,
#    'bootstrap': True},
#   {'n_estimators': 80,
#    'min_samples_split': 2,
#    'min_samples_leaf': 2,
#    'max_features': 'log2',
#    'max_depth': 1,
#    'bootstrap': True},
#   {'n_estimators': 120,
#    'min_samples_split': 10,
#    'min_samples_leaf': 1,
#    'max_features': 'log2',
#    'max_depth': 10,
#    'bootstrap': True},
#   {'n_estimators': 280,
#    'min_samples_split': 2,
#    'min_samples_leaf': 2,
#    'max_features': 'sqrt',
#    'max_depth': 10,
#    'bootstrap': False},
#   {'n_estimators': 400,
#    'min_samples_split': 10,
#    'min_samples_leaf': 1,
#    'max_features': 'sqrt',
#    'max_depth': 10,
#    'bootstrap': True},
#   {'n_estimators': 360,
#    'min_samples_split': 2,
#    'min_samples_leaf': 4,
#    'max_features': 'sqrt',
#    'max_depth': 10,
#    'bootstrap': False},
#   {'n_estimators': 160,
#    'min_samples_split': 10,
#    'min_samples_leaf': 4,
#    'max_features': 'sqrt',
#    'max_depth': None,
#    'bootstrap': True},
#   {'n_estimators': 280,
#    'min_samples_split': 2,
#    'min_samples_leaf': 2,
#    'max_features': 'log2',
#    'max_depth': 20,
#    'bootstrap': False},
#   {'n_estimators': 360,
#    'min_samples_split': 10,
#    'min_samples_leaf': 1,
#    'max_features': 'sqrt',
#    'max_depth': 1,
#    'bootstrap': False},
#   {'n_estimators': 320,
#    'min_samples_split': 5,
#    'min_samples_leaf': 1,
#    'max_features': 'sqrt',
#    'max_depth': 1,
#    'bootstrap': True},
#   {'n_estimators': 320,
#    'min_samples_split': 10,
#    'min_samples_leaf': 1,
#    'max_features': 'sqrt',
#    'max_depth': 20,
#    'bootstrap': True},
#   {'n_estimators': 200,
#    'min_samples_split': 2,
#    'min_samples_leaf': 1,
#    'max_features': 'log2',
#    'max_depth': 1,
#    'bootstrap': True},
#   {'n_estimators': 120,
#    'min_samples_split': 10,
#    'min_samples_leaf': 2,
#    'max_features': 'log2',
#    'max_depth': 1,
#    'bootstrap': True},
#   {'n_estimators': 400,
#    'min_samples_split': 2,
#    'min_samples_leaf': 1,
#    'max_features': 'sqrt',
#    'max_depth': 10,
#    'bootstrap': True},
#   {'n_estimators': 200,
#    'min_samples_split': 10,
#    'min_samples_leaf': 2,
#    'max_features': 'log2',
#    'max_depth': 1,
#    'bootstrap': True},
#   {'n_estimators': 400,
#    'min_samples_split': 5,
#    'min_samples_leaf': 2,
#    'max_features': 'sqrt',
#    'max_depth': 10,
#    'bootstrap': False},
#   {'n_estimators': 240,
#    'min_samples_split': 5,
#    'min_samples_leaf': 1,
#    'max_features': 'log2',
#    'max_depth': 20,
#    'bootstrap': False},
#   {'n_estimators': 160,
#    'min_samples_split': 5,
#    'min_samples_leaf': 4,
#    'max_features': 'log2',
#    'max_depth': 10,
#    'bootstrap': True},
#   {'n_estimators': 240,
#    'min_samples_split': 5,
#    'min_samples_leaf': 4,
#    'max_features': 'log2',
#    'max_depth': None,
#    'bootstrap': False},
#   {'n_estimators': 120,
#    'min_samples_split': 10,
#    'min_samples_leaf': 1,
#    'max_features': 'log2',
#    'max_depth': 1,
#    'bootstrap': False},
#   {'n_estimators': 80,
#    'min_samples_split': 5,
#    'min_samples_leaf': 4,
#    'max_features': 'log2',
#    'max_depth': 10,
#    'bootstrap': False},
#   {'n_estimators': 80,
#    'min_samples_split': 2,
#    'min_samples_leaf': 1,
#    'max_features': 'log2',
#    'max_depth': 20,
#    'bootstrap': False},
#   {'n_estimators': 400,
#    'min_samples_split': 5,
#    'min_samples_leaf': 4,
#    'max_features': 'sqrt',
#    'max_depth': 20,
#    'bootstrap': True},
#   {'n_estimators': 80,
#    'min_samples_split': 2,
#    'min_samples_leaf': 2,
#    'max_features': 'sqrt',
#    'max_depth': 1,
#    'bootstrap': False},
#   {'n_estimators': 200,
#    'min_samples_split': 10,
#    'min_samples_leaf': 1,
#    'max_features': 'log2',
#    'max_depth': 10,
#    'bootstrap': True},
#   {'n_estimators': 80,
#    'min_samples_split': 5,
#    'min_samples_leaf': 4,
#    'max_features': 'sqrt',
#    'max_depth': 1,
#    'bootstrap': True},
#   {'n_estimators': 240,
#    'min_samples_split': 2,
#    'min_samples_leaf': 2,
#    'max_features': 'sqrt',
#    'max_depth': None,
#    'bootstrap': True},
#   {'n_estimators': 400,
#    'min_samples_split': 10,
#    'min_samples_leaf': 4,
#    'max_features': 'sqrt',
#    'max_depth': 20,
#    'bootstrap': True},
#   {'n_estimators': 200,
#    'min_samples_split': 10,
#    'min_samples_leaf': 2,
#    'max_features': 'sqrt',
#    'max_depth': 10,
#    'bootstrap': False},
#   {'n_estimators': 400,
#    'min_samples_split': 10,
#    'min_samples_leaf': 4,
#    'max_features': 'log2',
#    'max_depth': 20,
#    'bootstrap': False},
#   {'n_estimators': 240,
#    'min_samples_split': 5,
#    'min_samples_leaf': 2,
#    'max_features': 'sqrt',
#    'max_depth': 10,
#    'bootstrap': True},
#   {'n_estimators': 40,
#    'min_samples_split': 10,
#    'min_samples_leaf': 1,
#    'max_features': 'log2',
#    'max_depth': None,
#    'bootstrap': False},
#   {'n_estimators': 120,
#    'min_samples_split': 10,
#    'min_samples_leaf': 1,
#    'max_features': 'log2',
#    'max_depth': None,
#    'bootstrap': False},
#   {'n_estimators': 160,
#    'min_samples_split': 2,
#    'min_samples_leaf': 2,
#    'max_features': 'log2',
#    'max_depth': 20,
#    'bootstrap': True},
#   {'n_estimators': 40,
#    'min_samples_split': 2,
#    'min_samples_leaf': 4,
#    'max_features': 'sqrt',
#    'max_depth': 1,
#    'bootstrap': False},
#   {'n_estimators': 240,
#    'min_samples_split': 10,
#    'min_samples_leaf': 4,
#    'max_features': 'sqrt',
#    'max_depth': 1,
#    'bootstrap': True},
#   {'n_estimators': 320,
#    'min_samples_split': 2,
#    'min_samples_leaf': 2,
#    'max_features': 'sqrt',
#    'max_depth': None,
#    'bootstrap': True},
#   {'n_estimators': 200,
#    'min_samples_split': 5,
#    'min_samples_leaf': 1,
#    'max_features': 'sqrt',
#    'max_depth': 1,
#    'bootstrap': False},
#   {'n_estimators': 320,
#    'min_samples_split': 5,
#    'min_samples_leaf': 1,
#    'max_features': 'log2',
#    'max_depth': None,
#    'bootstrap': True},
#   {'n_estimators': 360,
#    'min_samples_split': 2,
#    'min_samples_leaf': 1,
#    'max_features': 'sqrt',
#    'max_depth': 10,
#    'bootstrap': False},
#   {'n_estimators': 400,
#    'min_samples_split': 2,
#    'min_samples_leaf': 4,
#    'max_features': 'sqrt',
#    'max_depth': 1,
#    'bootstrap': True},
#   {'n_estimators': 120,
#    'min_samples_split': 10,
#    'min_samples_leaf': 2,
#    'max_features': 'sqrt',
#    'max_depth': 10,
#    'bootstrap': True},
#   {'n_estimators': 160,
#    'min_samples_split': 5,
#    'min_samples_leaf': 2,
#    'max_features': 'log2',
#    'max_depth': 10,
#    'bootstrap': False},
#   {'n_estimators': 160,
#    'min_samples_split': 2,
#    'min_samples_leaf': 4,
#    'max_features': 'sqrt',
#    'max_depth': 20,
#    'bootstrap': False},
#   {'n_estimators': 120,
#    'min_samples_split': 10,
#    'min_samples_leaf': 4,
#    'max_features': 'log2',
#    'max_depth': None,
#    'bootstrap': False},
#   {'n_estimators': 320,
#    'min_samples_split': 10,
#    'min_samples_leaf': 2,
#    'max_features': 'log2',
#    'max_depth': None,
#    'bootstrap': True},
#   {'n_estimators': 360,
#    'min_samples_split': 10,
#    'min_samples_leaf': 1,
#    'max_features': 'log2',
#    'max_depth': 1,
#    'bootstrap': False},
#   {'n_estimators': 320,
#    'min_samples_split': 10,
#    'min_samples_leaf': 4,
#    'max_features': 'log2',
#    'max_depth': 10,
#    'bootstrap': False},
#   {'n_estimators': 240,
#    'min_samples_split': 2,
#    'min_samples_leaf': 4,
#    'max_features': 'log2',
#    'max_depth': 20,
#    'bootstrap': True},
#   {'n_estimators': 200,
#    'min_samples_split': 2,
#    'min_samples_leaf': 2,
#    'max_features': 'sqrt',
#    'max_depth': None,
#    'bootstrap': False},
#   {'n_estimators': 280,
#    'min_samples_split': 5,
#    'min_samples_leaf': 4,
#    'max_features': 'log2',
#    'max_depth': 20,
#    'bootstrap': False},
#   {'n_estimators': 240,
#    'min_samples_split': 10,
#    'min_samples_leaf': 1,
#    'max_features': 'log2',
#    'max_depth': None,
#    'bootstrap': True},
#   {'n_estimators': 80,
#    'min_samples_split': 2,
#    'min_samples_leaf': 2,
#    'max_features': 'sqrt',
#    'max_depth': 10,
#    'bootstrap': False},
#   {'n_estimators': 240,
#    'min_samples_split': 10,
#    'min_samples_leaf': 1,
#    'max_features': 'sqrt',
#    'max_depth': 10,
#    'bootstrap': True},
#   {'n_estimators': 40,
#    'min_samples_split': 5,
#    'min_samples_leaf': 1,
#    'max_features': 'log2',
#    'max_depth': None,
#    'bootstrap': False},
#   {'n_estimators': 120,
#    'min_samples_split': 10,
#    'min_samples_leaf': 4,
#    'max_features': 'log2',
#    'max_depth': 20,
#    'bootstrap': True},
#   {'n_estimators': 160,
#    'min_samples_split': 2,
#    'min_samples_leaf': 1,
#    'max_features': 'sqrt',
#    'max_depth': 10,
#    'bootstrap': False},
#   {'n_estimators': 120,
#    'min_samples_split': 5,
#    'min_samples_leaf': 2,
#    'max_features': 'log2',
#    'max_depth': 1,
#    'bootstrap': False},
#   {'n_estimators': 40,
#    'min_samples_split': 10,
#    'min_samples_leaf': 4,
#    'max_features': 'log2',
#    'max_depth': 1,
#    'bootstrap': True},
#   {'n_estimators': 40,
#    'min_samples_split': 5,
#    'min_samples_leaf': 1,
#    'max_features': 'sqrt',
#    'max_depth': 20,
#    'bootstrap': False},
#   {'n_estimators': 120,
#    'min_samples_split': 2,
#    'min_samples_leaf': 1,
#    'max_features': 'log2',
#    'max_depth': 10,
#    'bootstrap': False},
#   {'n_estimators': 40,
#    'min_samples_split': 5,
#    'min_samples_leaf': 4,
#    'max_features': 'log2',
#    'max_depth': 1,
#    'bootstrap': False},
#   {'n_estimators': 200,
#    'min_samples_split': 2,
#    'min_samples_leaf': 1,
#    'max_features': 'log2',
#    'max_depth': None,
#    'bootstrap': False},
#   {'n_estimators': 400,
#    'min_samples_split': 10,
#    'min_samples_leaf': 1,
#    'max_features': 'sqrt',
#    'max_depth': 20,
#    'bootstrap': True},
#   {'n_estimators': 120,
#    'min_samples_split': 5,
#    'min_samples_leaf': 4,
#    'max_features': 'sqrt',
#    'max_depth': 10,
#    'bootstrap': True},
#   {'n_estimators': 360,
#    'min_samples_split': 10,
#    'min_samples_leaf': 1,
#    'max_features': 'log2',
#    'max_depth': None,
#    'bootstrap': False},
#   {'n_estimators': 360,
#    'min_samples_split': 10,
#    'min_samples_leaf': 2,
#    'max_features': 'log2',
#    'max_depth': None,
#    'bootstrap': False},
#   {'n_estimators': 40,
#    'min_samples_split': 2,
#    'min_samples_leaf': 1,
#    'max_features': 'sqrt',
#    'max_depth': 10,
#    'bootstrap': True},
#   {'n_estimators': 400,
#    'min_samples_split': 2,
#    'min_samples_leaf': 4,
#    'max_features': 'log2',
#    'max_depth': 10,
#    'bootstrap': False},
#   {'n_estimators': 400,
#    'min_samples_split': 5,
#    'min_samples_leaf': 4,
#    'max_features': 'log2',
#    'max_depth': None,
#    'bootstrap': False},
#   {'n_estimators': 240,
#    'min_samples_split': 10,
#    'min_samples_leaf': 2,
#    'max_features': 'log2',
#    'max_depth': 10,
#    'bootstrap': False}],
#  'split0_test_Recall_Class1': array([0.27961737, 0.77041943, 0.80279617, 0.77041943, 0.31640912,
#         0.81089036, 0.81530537, 0.7718911 , 0.80721118, 0.80573951,
#         0.80426784, 0.80573951, 0.2950699 , 0.80279617, 0.81456954,
#         0.7740986 , 0.80353201, 0.76894776, 0.7718911 , 0.81089036,
#         0.77262693, 0.77115526, 0.80721118, 0.80941869, 0.80794702,
#         0.2950699 , 0.2950699 , 0.77557027, 0.77262693, 0.77483444,
#         0.31640912, 0.77336277, 0.76968359, 0.77483444, 0.77262693,
#         0.80058867, 0.80647535, 0.3473142 , 0.35025754, 0.80058867,
#         0.27961737, 0.2950699 , 0.77115526, 0.27961737, 0.77115526,
#         0.81309787, 0.77041943, 0.80721118, 0.2950699 , 0.77041943,
#         0.80941869, 0.80279617, 0.31714496, 0.77336277, 0.31640912,
#         0.80500368, 0.80058867, 0.77115526, 0.80206034, 0.7718911 ,
#         0.8116262 , 0.80868286, 0.799117  , 0.33774834, 0.28550405,
#         0.80573951, 0.27740986, 0.80721118, 0.7718911 , 0.36497425,
#         0.76894776, 0.76968359, 0.80573951, 0.80573951, 0.80206034,
#         0.3473142 , 0.76968359, 0.80206034, 0.81456954, 0.80426784,
#         0.80206034, 0.77998528, 0.77262693, 0.81015453, 0.80279617,
#         0.76894776, 0.2950699 , 0.33774834, 0.81456954, 0.76674025,
